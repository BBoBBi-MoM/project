# %% [markdown]
# ---
# ## 라이브러리 불러오기
# ---

# %%
import sys,os
import pickle
utils_path = os.path.join(os.path.join(os.environ['USERPROFILE']), 'Desktop','utils')
sys.path.append(utils_path)

from custom_function import *


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier

from pycaret.classification import *

# %% [markdown]
# ---
# ## 데이터 확인
# ---

# %%
ufc_df = pd.read_csv('./datasets/ufc/data.csv')
ufc_df.head()
# Out:
#        R_fighter          B_fighter        Referee        date  \
# 0   Adrian Yanez      Gustavo Lopez  Chris Tognoni  2021-03-20
# 1   Trevin Giles      Roman Dolidze      Herb Dean  2021-03-20
# 2    Tai Tuivasa    Harry Hunsucker      Herb Dean  2021-03-20
# 3  Cheyanne Buys  Montserrat Conejo     Mark Smith  2021-03-20
# 4  Marion Reneau      Macy Chiasson     Mark Smith  2021-03-20
#
#                  location Winner  title_bout       weight_class  B_avg_KD  \
# 0  Las Vegas, Nevada, USA    Red       False       Bantamweight     0.000
# 1  Las Vegas, Nevada, USA    Red       False       Middleweight     0.500
# 2  Las Vegas, Nevada, USA    Red       False        Heavyweight       NaN
# 3  Las Vegas, Nevada, USA   Blue       False   WomenStrawweight       NaN
# 4  Las Vegas, Nevada, USA   Blue       False  WomenBantamweight     0.125
#
#    B_avg_opp_KD  B_avg_SIG_STR_pct  B_avg_opp_SIG_STR_pct  B_avg_TD_pct  \
# ...

# %% [markdown]
# ---
# 불필요한 특성 제거

# %%
ufc_df.drop(['R_fighter','B_fighter','Referee','date','location','title_bout','weight_class'],axis=1,inplace=True)
ufc_df
# Out:
#      Winner  B_avg_KD  B_avg_opp_KD  B_avg_SIG_STR_pct  B_avg_opp_SIG_STR_pct  \
# 0       Red     0.000           0.0           0.420000                0.49500
# 1       Red     0.500           0.0           0.660000                0.30500
# 2       Red       NaN           NaN                NaN                    NaN
# 3      Blue       NaN           NaN                NaN                    NaN
# 4      Blue     0.125           0.0           0.535625                0.57875
# ...     ...       ...           ...                ...                    ...
# 6007    Red       NaN           NaN                NaN                    NaN
# 6008    Red       NaN           NaN                NaN                    NaN
# 6009    Red       NaN           NaN                NaN                    NaN
# 6010    Red       NaN           NaN                NaN                    NaN
# 6011    Red       NaN           NaN                NaN                    NaN
#
# ...

# %%
red_col_list = list()
blue_col_list = list()
etc_col_list = list()

for col in ufc_df.columns:
    if col[:2]=='B_':
        blue_col_list.append(col)
    elif col[:2] == 'R_':
        red_col_list.append(col)
    else:
        etc_col_list.append(col)

# %%
light_df = ufc_df[blue_col_list+red_col_list+etc_col_list]
light_df = light_df.dropna()
light_df
# Out:
#       B_avg_KD  B_avg_opp_KD  B_avg_SIG_STR_pct  B_avg_opp_SIG_STR_pct  \
# 0     0.000000         0.000           0.420000               0.495000
# 1     0.500000         0.000           0.660000               0.305000
# 4     0.125000         0.000           0.535625               0.578750
# 5     0.000000         0.000           0.515000               0.473750
# 6     0.046875         0.125           0.459277               0.404687
# ...        ...           ...                ...                    ...
# 5759  0.000000         0.000           0.737500               0.475000
# 5767  0.000000         0.000           0.500000               0.350000
# 5799  0.500000         0.500           0.640000               0.665000
# 5840  0.000000         0.000           0.460000               0.230000
# 5884  0.500000         0.000           0.642500               0.235000
#
#       B_avg_TD_pct  B_avg_opp_TD_pct  B_avg_SUB_ATT  B_avg_opp_SUB_ATT  \
# ...

# %%
light_df = light_df.drop(light_df[light_df['Winner'] == 2].index)

# %%
light_df
# Out:
#       B_avg_KD  B_avg_opp_KD  B_avg_SIG_STR_pct  B_avg_opp_SIG_STR_pct  \
# 0     0.000000         0.000           0.420000               0.495000
# 1     0.500000         0.000           0.660000               0.305000
# 4     0.125000         0.000           0.535625               0.578750
# 5     0.000000         0.000           0.515000               0.473750
# 6     0.046875         0.125           0.459277               0.404687
# ...        ...           ...                ...                    ...
# 5759  0.000000         0.000           0.737500               0.475000
# 5767  0.000000         0.000           0.500000               0.350000
# 5799  0.500000         0.500           0.640000               0.665000
# 5840  0.000000         0.000           0.460000               0.230000
# 5884  0.500000         0.000           0.642500               0.235000
#
#       B_avg_TD_pct  B_avg_opp_TD_pct  B_avg_SUB_ATT  B_avg_opp_SUB_ATT  \
# ...

# %%
b_stance_one_hot = pd.get_dummies(light_df['B_Stance'])
new_b_col_list =list()
for idx in range(len(b_stance_one_hot.columns)):
    new_b_col_list.append('B '+b_stance_one_hot.columns[idx])
b_stance_one_hot.columns = new_b_col_list

# %%
r_stance_one_hot = pd.get_dummies(light_df['R_Stance'])
new_r_col_list =list()
for idx in range(len(r_stance_one_hot.columns)):
    new_r_col_list.append('R '+r_stance_one_hot.columns[idx])
r_stance_one_hot.columns = new_r_col_list

# %%
light_df.drop(['B_Stance','R_Stance'],axis=1,inplace=True)
light_df['Winner']=light_df['Winner'].map({'Blue':0,'Red':1,'Draw':2})

# %%
age_max = max(light_df['B_age'].max(),light_df['R_age'].max())
age_min = min(light_df['B_age'].min(),light_df['R_age'].min())
height_max = max(light_df['B_Height_cms'].max(),light_df['R_Height_cms'].max())
height_min = min(light_df['B_Height_cms'].min(),light_df['R_Height_cms'].min())
reach_max = max(light_df['B_Reach_cms'].max(),light_df['R_Reach_cms'].max())
reach_min = min(light_df['B_Reach_cms'].min(),light_df['R_Reach_cms'].min())
weight_max = max(light_df['B_Weight_lbs'].max(),light_df['R_Weight_lbs'].max())
weight_min = min(light_df['B_Weight_lbs'].min(),light_df['R_Weight_lbs'].min())

# %%
light_df['B_age'] = (light_df['B_age']-age_min)/(age_max-age_min)
light_df['R_age'] = (light_df['R_age']-age_min)/(age_max-age_min)

light_df['B_Height_cms'] = (light_df['B_Height_cms']-height_min)/(height_max-height_min)
light_df['R_Height_cms'] = (light_df['R_Height_cms']-height_min)/(height_max-height_min)

light_df['B_Reach_cms'] = (light_df['B_Reach_cms']-reach_min)/(reach_max-reach_min)
light_df['R_Reach_cms'] = (light_df['R_Reach_cms']-reach_min)/(reach_max-reach_min)

light_df['B_Weight_lbs'] = (light_df['B_Weight_lbs']-weight_min)/(weight_max-weight_min)
light_df['R_Weight_lbs'] = (light_df['R_Weight_lbs']-weight_min)/(weight_max-weight_min)

# %%
min_max_df = pd.concat([b_stance_one_hot,r_stance_one_hot,light_df],axis=1)

# %%
min_max_df
# Out:
#       B Open Stance  B Orthodox  B Southpaw  B Switch  R Open Stance  \
# 0                 0           1           0         0              0
# 1                 0           1           0         0              0
# 4                 0           1           0         0              0
# 5                 0           0           0         1              0
# 6                 0           1           0         0              0
# ...             ...         ...         ...       ...            ...
# 5759              0           1           0         0              0
# 5767              0           1           0         0              0
# 5799              0           1           0         0              0
# 5840              0           1           0         0              0
# 5884              0           0           1         0              0
#
#       R Orthodox  R Southpaw  R Switch  B_avg_KD  B_avg_opp_KD  \
# 0              1           0         0  0.000000         0.000
# ...

# %%
for col in min_max_df.columns:
    if col in ['B_age','R_age','B_Height_cms','R_Height_cms','B_Reach_cms','R_Reach_cms','B_Weight_lbs','R_Weight_lbs']:
        min_max_df[col] =  ((light_df[col] - light_df[col].min())/(light_df[col].max()-light_df[col].min())).copy()

# %%
min_max_df
# Out:
#       B Open Stance  B Orthodox  B Southpaw  B Switch  R Open Stance  \
# 0                 0           1           0         0              0
# 1                 0           1           0         0              0
# 4                 0           1           0         0              0
# 5                 0           0           0         1              0
# 6                 0           1           0         0              0
# ...             ...         ...         ...       ...            ...
# 5759              0           1           0         0              0
# 5767              0           1           0         0              0
# 5799              0           1           0         0              0
# 5840              0           1           0         0              0
# 5884              0           0           1         0              0
#
#       R Orthodox  R Southpaw  R Switch  B_avg_KD  B_avg_opp_KD  \
# 0              1           0         0  0.000000         0.000
# ...

# %%
min_max_df['B_age']
# Out:
# 0       0.407407
# 1       0.444444
# 4       0.333333
# 5       0.259259
# 6       0.555556
#           ...
# 5759    0.370370
# 5767    0.333333
# 5799    0.111111
# 5840    0.333333
# 5884    0.000000
# Name: B_age, Length: 3914, dtype: float64

# %%
min_max_df = min_max_df.sample(frac=True)

# %%
min_max_df
# Out:
#       B Open Stance  B Orthodox  B Southpaw  B Switch  R Open Stance  \
# 1212              0           1           0         0              0
# 3997              0           1           0         0              0
# 3434              0           1           0         0              0
# 4665              0           1           0         0              0
# 438               0           0           1         0              0
# ...             ...         ...         ...       ...            ...
# 4324              0           0           1         0              0
# 576               0           1           0         0              0
# 4882              0           0           1         0              0
# 3466              0           1           0         0              0
# 1922              0           0           1         0              0
#
#       R Orthodox  R Southpaw  R Switch  B_avg_KD  B_avg_opp_KD  \
# 1212           1           0         0  0.515625      0.003906
# ...

# %%
train_df, test_df = min_max_df.iloc[:int(len(min_max_df)*0.8),:],min_max_df.iloc[int(len(min_max_df)*0.8):,:]

# %%
classifier_selector = setup(train_df,target='Winner')
# Out:
# <style type="text/css">
# #T_80f68_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_80f68">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80f68_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_80f68_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80f68_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_80f68_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_80f68_row0_col1" class="data row0 col1" >2535</td>
#     </tr>
#     <tr>
#       <th id="T_80f68_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_80f68_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_80f68_row1_col1" class="data row1 col1" >Winner</td>
#     </tr>
#     <tr>
#       <th id="T_80f68_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model= compare_models()
# Out:
# <style type="text/css">
# #T_bcc76 th {
#   text-align: left;
# }
# ...

# %%
train_df['B Open Stance']
# Out:
# 1212    0
# 3997    0
# 3434    0
# 4665    0
# 438     0
#        ..
# 2203    0
# 1798    0
# 2512    0
# 1389    0
# 1108    0
# Name: B Open Stance, Length: 3131, dtype: uint8

# %%
train_X, train_y = train_df.iloc[:,:-1].values, train_df.iloc[:,-1].values
test_X, test_y = test_df.iloc[:,:-1].values , test_df.iloc[:,-1].values

# %%
result_list = list()
kfold_dict = kfold_generator(train_df)

# %%
kfold_dict[0][0]
# Out:
#       B Open Stance  B Orthodox  B Southpaw  B Switch  R Open Stance  \
# 4794              0           0           1         0              0
# 2146              0           1           0         0              0
# 672               0           1           0         0              0
# 3049              0           0           1         0              0
# 1085              0           1           0         0              0
# ...             ...         ...         ...       ...            ...
# 688               0           1           0         0              0
# 1300              0           1           0         0              0
# 3531              0           1           0         0              0
# 4291              0           1           0         0              0
# 2876              0           1           0         0              0
#
#       R Orthodox  R Southpaw  R Switch  B_avg_KD  B_avg_opp_KD  ...  \
# 4794           1           0         0  0.000000      0.000000  ...
# ...

# %%
for n in [10,50,100,200]:
    for depth in [2,3,4,5]:
        for lr in [5e-2,1e-2,1e-1,5e-1,1]:
            gbc = GradientBoostingClassifier(n_estimators=n, max_depth=depth, learning_rate=lr)
            
            avg_accuracy = 0.0
            for idx in range(5):
                train_df,val_df = kfold_dict[idx][0], kfold_dict[idx][1]
                train_X, train_y = train_df.iloc[:,:-1].values, train_df.iloc[:,-1].values
                val_X, val_y = val_df.iloc[:,:-1].values, val_df.iloc[:,-1].values

                gbc.fit(train_X,train_y)
                pred = gbc.predict(val_X)

                fold_accuracy = (pred == val_y).sum()/len(val_y)*100
                avg_accuracy += fold_accuracy/5

            file_name = f'./pkl/gbc_{n}_{depth}_{lr}.pkl'
            joblib.dump(gbc,filename=file_name)
            result_list.append((avg_accuracy,n,depth,lr,file_name))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 12
#       9 train_X, train_y = train_df.iloc[:,:-1].values, train_df.iloc[:,-1].values
#      10 val_X, val_y = val_df.iloc[:,:-1].values, val_df.iloc[:,-1].values
# ---> 12 gbc.fit(train_X,train_y)
#      13 pred = gbc.predict(val_X)
#      15 fold_accuracy = (pred == val_y).sum()/len(val_y)*100
#
# File c:\ProgramData\Anaconda3\envs\ML\lib\site-packages\sklearn\ensemble\_gb.py:498, in BaseGradientBoosting.fit(self, X, y, sample_weight, monitor)
#     495 X_idx_sorted = None
#     497 # fit the boosting stages
# --> 498 n_stages = self._fit_stages(
#     499     X, y, raw_predictions, sample_weight, self._rng, X_val, y_val,
#     500     sample_weight_val, begin_at_stage, monitor, X_idx_sorted)
#     502 # change shape of arrays after fit (early-stopping or additional ests)
# ...

# %%
max(result_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 max(result_list)
#
# NameError: name 'result_list' is not defined
